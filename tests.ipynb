# %%
from read_config import read_config
from conv_layer import get_cnn_configurations

# %%
get_cnn_configurations(60,0.5,verbose=True)
# Out:
# Output size =  30
# s =  2 , p =  0 , f =  2
# s =  2 , p =  1 , f =  4
# s =  2 , p =  2 , f =  6
# s =  2 , p =  3 , f =  8
# [{'s': 2, 'p': 0, 'f': 2},
#  {'s': 2, 'p': 1, 'f': 4},
#  {'s': 2, 'p': 2, 'f': 6},
#  {'s': 2, 'p': 3, 'f': 8}]

# %%
read_config("config_cnn_1d.INI",verbose = False)
# Out:
# Samples of the training data
# Epoch nr | Loss
# 0 3291.125
# 1 3291.125
# 2 3291.125
# 3 3291.125
# 4 3291.125
# 5 3291.125
# 6 3291.125
# 7 3291.125
# 8 3291.125
# 9 3291.125
# 10 3291.125
# 11 3291.125
# 12 3291.125
# 13 3291.125
# 14 3291.125
# 15 3291.125
# 16 3291.125
# 17 3291.125
# 18 3291.125
# 19 3291.125
# 20 3291.125
# 21 3291.125
# 22 3291.125
# 23 3291.125
# 24 3291.125
# 25 3291.125
# 26 3291.125
# 27 3291.125
# 28 3291.125
# 29 3291.125
# 30 3291.125
# 31 3291.125
# 32 3291.125
# 33 3291.125
# 34 3291.125
# 35 3291.125
# 36 3291.125
# 37 3291.125
# 38 3291.125
# 39 3291.125
# 40 3291.125
# 41 3291.125
# 42 3291.125
# 43 3291.125
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-5b9d62a22c78> in <module>
# ----> 1 read_config("config_cnn_1d.INI",verbose = False)
#
# ...

# %%
plot_pred,net = read_config("config_cnn_2d.INI")
# Out:
# Samples of the training data
# Epoch nr | Loss
# 0 0.616763588441888
# 1 0.1601429905072804
# 2 0.09107716997849667
# 3 0.05335605042820153
# 4 0.050345434567680675
# 5 0.03399099304785729
# 6 0.042395262044808237
# 7 0.01932562195134218
# 8 0.020067122247834742
# 9 0.019658089169425203
# 1  misclassifications for cross
# 1  misclassifications for circle
# 2  misclassifications for triangle
# 31  misclassifications for square
# 29  misclassifications for pentagon
#
#  Confusion matrix
# [[1.9846e+02 1.4400e+00 1.0000e-01 0.0000e+00 0.0000e+00]
#  [0.0000e+00 1.9628e+02 0.0000e+00 0.0000e+00 3.7200e+00]
#  [1.0500e+00 1.0000e-02 1.9612e+02 2.7300e+00 9.0000e-02]
#  [0.0000e+00 3.0000e-02 2.9800e+00 1.7390e+02 2.3090e+01]
#  [0.0000e+00 6.0000e-01 0.0000e+00 1.0030e+01 1.8937e+02]]
#
# Index for misclassified images
# (array([ 48, 103, 108, 138, 224, 238, 293, 310, 313, 333, 348, 357, 368,
#        403, 434, 453, 518, 609, 633, 638, 643, 724, 744, 748, 754, 794,
# ...

# %%
plot_pred(11)
# Out:
# (5, 1000)

# %%
net.layers[0].plot_kernel()

# %%
plot_pred,net = read_config("config_cnn_2d_1d.INI",verbose=False)
# Out:
# Samples of the training data
# Epoch nr | Loss
# 0 0.7055031508627511
# 1 0.20024314602214055
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-6d3ad906b721> in <module>
# ----> 1 plot_pred,net = read_config("config_cnn_2d_1d.INI",verbose=False)
#
# c:\Users\hakon\Documents\Studier\FM V21\Master\neural_net\read_config.py in read_config(filename, verbose)
#     275         regularizer=reg,
#     276         validation= validation,
# --> 277         verbose = verbose)
#     278
#     279     if type == "2D":
#
# c:\Users\hakon\Documents\Studier\FM V21\Master\neural_net\train.py in train(net, inputs, targets, num_epochs, batch_size, loss, optimizer, regularizer, validation, verbose)
#      63
#      64             grad = loss.grad(predicted,targets[...,start:end])
# ---> 65             net.backward(grad,verbose = verbose)
#      66
# ...

# %%
plot_pred(0)

# %%
net.layers[2].plot_kernel()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-280bbf36f28e> in <module>
# ----> 1 net.layers[2].plot_kernel()
#
# c:\Users\hakon\Documents\Studier\FM V21\Master\neural_net\conv_layer.py in plot_kernel(self)
#      98     #plotting kernels
#      99     def plot_kernel(self):
# --> 100         kernels = self.flat_kernels.reshape(self.k_size*self.o_channels,self.k_size*self.i_channels)
#     101         plt.imshow(kernels)
#     102         plt.show()
#
# ValueError: cannot reshape array of size 16 into shape (4,16)
